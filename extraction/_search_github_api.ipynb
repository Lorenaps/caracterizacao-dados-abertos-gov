# %% [markdown]
# # Pesquisando por iniciativas/projetos com Dados Abertos Governamentais no Github

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# TODO:
#
# **Mapeamento das principais bibliotecas**
#
# - [API da Câmara dos deputados](https://dadosabertos.camara.leg.br/swagger/api.html)

# %%
search_strings_libraries = []

# %% [markdown]
# Devido a estrutura de pesquisa no github as palavras chaves utilizadas para o
# news não foram tão eficiente, visto que preciso adicionar palavras de busca ou
# de forma conter uma das palavras ou conter todas as palavras na sequencia especificada.
#
# Sendo assim:
# - '"projeto" and "dados governo"',
# - '"projeto" and "dados governamentais"',
# - '"projeto" and "monitora" and "dados" and "governo"'
#
# Não foram buscas efetivas, porém as palavras chaves inicias sim.

# %%
search_strings = [
            'dados abertos',
            'dados abertos brasil',
            'dados abertos governo',
            'dados abertos governamentais',
            'dados governamentais',
            'dados publicos abertos',
            'dados do governo',
            'analise de dados do governo',
            'analise de dados governamentais',
            'portal de dados do governo',
            'portal de dados governamentais',
            'portal publico do governo',
            'portal de dados abertos do governo',
        ]

# %% [markdown]
# 'consumir' e 'publicação' não retornaram resultados e por isso foram retirados a fim de adicionar palavras que retornem resultados melhores
# - 'consumir dados abertos do governo'
# - 'consumir dados abertos governamentais'
# - 'publicação de dados abertos do governo',
# - 'publicação de dados governamentais',

# %%
sort = '&sort=stars&order=desc'
url_base = 'https://api.github.com/search/repositories?q='
credentials=('lorenaps','')

# %% [markdown]
# Verificando o limite de requisições

# %%
t = requests.get('https://api.github.com/rate_limit', auth=credentials)
t.json()
# Out:
# {'rate': {'limit': 5000, 'remaining': 5000, 'reset': 1573219538},
#  'resources': {'core': {'limit': 5000, 'remaining': 5000, 'reset': 1573219538},
#   'graphql': {'limit': 5000, 'remaining': 5000, 'reset': 1573219538},
#   'integration_manifest': {'limit': 5000,
#    'remaining': 5000,
#    'reset': 1573219538},
#   'search': {'limit': 30, 'remaining': 30, 'reset': 1573215998}}}

# %%
columns=[
        'id',
        'full_name',
        'description',
        'owner_type', 
        'owner_api_url',
        'owner_url',
        'url',
        'api_url',
        'fork',
        'created_at',
        'updated_at',
        'size',
        'stargazers_count',
        'language',
        'has_issues',
        'has_wiki',
        'forks_count',
        'forks',
        'open_issues',
        'watchers',
        'timestamp_extract'
    ]

# %%
def add_result(item):
    
    df = pd.DataFrame([[
                        item.get('id'),
                        item.get('full_name', None),
                        item.get('description', None),      
                        item.get('owner').get('type', None),
                        item.get('owner').get('url', None),
                        item.get('owner').get('html_url', None),
                        item.get('html_url', None),
                        item.get('url', None),
                        item.get('fork', None),
                        item.get('created_at', None),
                        item.get('updated_at', None),
                        item.get('size', None),
                        item.get('stargazers_count', None),
                        item.get('language', None),
                        item.get('has_issues', None),
                        item.get('has_wiki', None),
                        item.get('forks_count', None),
                        item.get('forks', None),
                        item.get('open_issues', None),
                        item.get('watchers', None),
                        str(time.time()).split('.')[0]]], columns=columns)

    return df

# %%
def extract_results(data, results):
    
    for item in data.get('items', None):
        
        results = pd.concat([results, add_result(item)], ignore_index=True, sort=False)

    return results

# %% [markdown]
# Verificando limitação de extração de dados da API

# %%
page_35 = 'https://api.github.com/search/repositories?q=stars%3A%3E1&sort=stars&order=desc&page=35'
t = requests.get(page_35, auth=credentials)
t.json()
# Out:
# {'documentation_url': 'https://developer.github.com/v3/search/',
#  'message': 'Only the first 1000 search results are available'}

# %%
repositories_df = pd.DataFrame(columns=['id',
                                    'full_name',
                                    'description',
                                    'owner_type', 
                                    'owner_api_url',
                                    'owner_url',
                                    'url',
                                    'api_url',
                                    'fork',
                                    'created_at',
                                    'updated_at',
                                    'size',
                                    'stargazers_count',
                                    'language',
                                    'has_issues',
                                    'has_wiki',
                                    'forks_count',
                                    'forks',
                                    'open_issues',
                                    'watchers',
                                    'timestamp_extract',
                                    'commits',
                                    'contributors',])

# %%
def scroll_pages(url, repositories_df):
    
    print('\nPrimeira requisição')
    
    results = requests.get(url, auth=credentials)    
    data = dict(results.json())
    total = data.get('total_count', None)
        
    print(">>> Foram encontrados {0} resultados. Extraindo...".format(total))

    repositories_df = extract_results(data, repositories_df)
    
    iterations = total // 30 
    
    for iteracao in range(0, iterations):        
        header = dict(results.links)
        
        if header.get('next', False):
            next_url = header.get('next').get('url')
            
            print("\nNext url: {0}".format(next_url))
            
            results = requests.get(next_url, auth=credentials)
            data = dict(results.json())
            repositories_df = extract_results(data, repositories_df)
        
    return repositories_df

# %%
# %%time

for string in search_strings:
    url = url_base + string + sort
    print("\nExtraindo repositórios para a string: '{0}'".format(string))
    repositories_df = scroll_pages(url, repositories_df)
# Out:
# Extraindo repositórios para a string: 'dados abertos'
#
# Primeira requisição
# >>> Foram encontrados 370 resultados. Extraindo...
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=2
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=3
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=4
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=5
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=6
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=7
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=8
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=9
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=10
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=11
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=12
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos&sort=stars&order=desc&page=13
#
# Extraindo repositórios para a string: 'dados abertos brasil'
#
# Primeira requisição
# >>> Foram encontrados 34 resultados. Extraindo...
#
# Next url: https://api.github.com/search/repositories?q=dados+abertos+brasil&sort=stars&order=desc&page=2
#
# Extraindo repositórios para a string: 'dados abertos governo'
#
# Primeira requisição
# >>> Foram encontrados 23 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'dados abertos governamentais'
#
# Primeira requisição
# >>> Foram encontrados 13 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'dados governamentais'
#
# Primeira requisição
# >>> Foram encontrados 20 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'dados publicos abertos'
#
# Primeira requisição
# >>> Foram encontrados 8 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'dados do governo'
#
# Primeira requisição
# >>> Foram encontrados 69 resultados. Extraindo...
#
# Next url: https://api.github.com/search/repositories?q=dados+do+governo&sort=stars&order=desc&page=2
#
# Next url: https://api.github.com/search/repositories?q=dados+do+governo&sort=stars&order=desc&page=3
#
# Extraindo repositórios para a string: 'analise de dados do governo'
#
# Primeira requisição
# >>> Foram encontrados 11 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'analise de dados governamentais'
#
# Primeira requisição
# >>> Foram encontrados 4 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'portal de dados do governo'
#
# Primeira requisição
# >>> Foram encontrados 10 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'portal de dados governamentais'
#
# Primeira requisição
# >>> Foram encontrados 2 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'portal publico do governo'
#
# Primeira requisição
# >>> Foram encontrados 1 resultados. Extraindo...
#
# Extraindo repositórios para a string: 'portal de dados abertos do governo'
#
# Primeira requisição
# >>> Foram encontrados 5 resultados. Extraindo...
# CPU times: user 4.06 s, sys: 44.7 ms, total: 4.1 s
# Wall time: 44.8 s

# %%
repositories_df.describe()
# Out:
#                id              full_name  \
# count         570                    570
# unique        404                    404
# top     195294598  edsonmottac/go-to-doc
# freq            6                      6
#
#                                               description owner_type  \
# count                                                 534        570
# unique                                                370          2
# top     Plugin/Tema do Portal de Dados Abertos do Gove...       User
# freq                                                    6        466
#
#                                   owner_api_url  \
# count                                       570
# unique                                      354
# top     https://api.github.com/users/dadosgovbr
# freq                                         16
#
#                             owner_url  \
# count                             570
# unique                            354
# top     https://github.com/dadosgovbr
# freq                               16
#
#                                              url  \
# count                                        570
# unique                                       404
# top     https://github.com/edsonmottac/go-to-doc
# freq                                           6
#
#                                                   api_url   fork  \
# count                                                 570    570
# unique                                                404      1
# top     https://api.github.com/repos/edsonmottac/go-to...  False
# freq                                                    6    570
#
#                   created_at      ...      language  has_issues  has_wiki  \
# count                    570      ...           424         570       570
# unique                   404      ...            22           2         2
# top     2017-08-23T19:05:48Z      ...        Python        True      True
# freq                       6      ...            92         555       553
#
#        forks_count forks open_issues  watchers  timestamp_extract  commits  \
# count          570   570         570       570                570      0.0
# unique          16    16          14        25                 28      0.0
# top              0     0           0         0         1573215966      NaN
# freq           424   424         488       395                 30      NaN
#
#         contributors
# count            0.0
# unique           0.0
# top              NaN
# freq             NaN
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Extraindo Commits e Contributors

# %%
def extract_commits(url_repo):
    
    commits_url = url_repo + '/commits'  
    results = requests.get(commits_url, auth=credentials)
    
    # No caso do repositório estar vazio
    if results.status_code == 409:
        return None
    
    commits = len(results.json())

    header = dict(results.links)
    
    while header.get('next', False):
        next_url = header.get('next').get('url')        
        results = requests.get(next_url, auth=credentials)
        commits = commits + len(results.json())    
        header = dict(results.links)


    return commits

# %%
def extract_contributors(url_repo):
    
    contributors_url = url_repo + '/contributors'
    results = requests.get(contributors_url, auth=credentials)
    
    # No caso do repositório estar vazio
    if results.status_code == 204:
        return None
    
    contributors = len(results.json())

    header = dict(results.links)
    
    while header.get('next', False):
        next_url = header.get('next').get('url')
        results = requests.get(next_url, auth=credentials)
        contributors = contributors + len(results.json())
        header = dict(results.links)
    
    return contributors

# %%
# %%time
urls = repositories_df['api_url']

for url in urls:
        
    print('\n>>> ', url)
    
    repo = requests.get(url, auth=credentials)
    repo = dict(repo.json())
        
    commits = extract_commits(url)
    contributors = extract_contributors(url)

    print("Tem {0} Commits - {1} Contributors".format(commits,contributors))

    repositories_df.loc[repositories_df["api_url"] == url, 'commits'] = commits
    repositories_df.loc[repositories_df["api_url"] == url, 'contributors'] = contributors
# Out:
# >>>  https://api.github.com/repos/CamaraDosDeputados/dados-abertos
# Tem 28 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
# Tem 42 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/prefeiturasp/dados-educacao
# Tem 18 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
# Tem 40 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/kit
# Tem 361 Commits - 6 Contributors
#
# >>>  https://api.github.com/repos/mapaslivres/localidades
# Tem 69 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/odufrn/odufrn-downloader
# Tem 237 Commits - 6 Contributors
#
# >>>  https://api.github.com/repos/brasilopen/brasilopen
# Tem 10 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/vitorbaptista/dados-abertos-camara.gov.br
# Tem 31 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jonny-data/conheca-seu-vereador
# Tem 70 Commits - 6 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/processo-participacao-social-inda
# Tem 30 Commits - 7 Contributors
#
# >>>  https://api.github.com/repos/npi-ufc-qxd/dados-abertos
# Tem 118 Commits - 7 Contributors
#
# >>>  https://api.github.com/repos/thefonseca/jogo-politico
# Tem 29 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/zezente/opendata_aig_brazil
# Tem 214 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
# Tem 49 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/inepdadosabertos/api
# Tem 29 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/sigalei/api-camara-graphql
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
# Tem 159 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosabertosrn/DadosAbertosRN
# Tem 50 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/paulozip/acidentes-aereos
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/codigourbano/ocorrencias-transito-pmsp
# Tem 22 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/labhackercd/dados-abertos-2.0
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/api-siconv
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/transparenciahackday/dadosabertos.pt
# Tem 115 Commits - 7 Contributors
#
# >>>  https://api.github.com/repos/edumagol/Analise-Mapemaneto-Risco-Barragems-Brasil
# Tem 25 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/abevieiramota/dataset-cnpj
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ffknob/dados-abertos-elk
# Tem 49 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/andreloc/open-data-assembleia-legislativa-ce
# Tem 35 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/centraldedados/parlamento
# Tem 287 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/sjcdigital/Dados-Abertos-SJC
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/dados-abertos-gov-br
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danielmbicalho/Dados_repositorios_e_ferramentas
# Tem 7 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/FABdadosabertos/CENIPA
# Tem 24 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/luisleao/oicamara
# Tem 27 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/anaschwendler/workshop-bahia
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/kerollaine/eaicongresso
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/code-for-joinville/joinville-opendata.github.io
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/tcm-ceara/apilayer
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/Vnicius/dados-pb
# Tem 66 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/peterleiva/CNES-API
# Tem 28 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/juliohenriquerocha/cidade-mapeada-lsi
# Tem 28 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/Dayof/OpenData_BolsaFamilia
# Tem 94 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/sergioamorim/lattes_mining
# Tem 43 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/pyladiespb-org/minicurso-analise-descritiva-dados-abertos
# Tem 34 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/ReciHub/Dados-Abertos-Recife
# Tem 12 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/isweluiz/verba_indenizatoria__cldf
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/alvarofpp/analise-ufrn-python-day-2018
# Tem 17 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/mapaslivres/zonas-eleitorais
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nilzao/cmspwiki
# Tem 93 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/planejamentoGovBr/PDA-institucional-MP
# Tem 915 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/okfn-brasil/gastos_abertos_dados
# Tem 66 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/kheronn/transparencia-pr
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nymarya/prf_api
# Tem 55 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/marceloandriolli/informacao-salva
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/acvilarim/politicAPI
# Tem 15 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/geovannyAvelar/Dados-Abertos-Campeonato-Brasileiro
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/GETIPUSP/dadosabertosnasaude
# Tem 14 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/CodeForCuritiba/dadosabertos_prefs
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/djalmaaraujo/dadosabertos-cnpj-converter
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nucleo-digital/sp-mapas
# Tem 87 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/elciusferreira/propositions-analysis
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateusgrb/app-procon
# Tem 82 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/thiagorondon/Deputando
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-package
# Tem 334 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/culturagovbr/PDA-Sistema-MinC
# Tem 78 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/tbai/opendata-br
# Tem 14 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/neonlee/DadosAbertos
# Tem 2 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/Ermesoml/DadosAbertos-Vue
# Tem 24 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/fmca/cinexplorer
# Tem 52 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/interlegis/interlegis.portalmodelo.api
# Tem 25 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/codigourbano/dados-abertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/anp-qualidade/dados-abertos-pmqc
# Tem 86 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/sergiohampel/hoteis-recife
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/wseidel/serveoquantoganha
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/paraibatransparente/portal-symfony
# Tem 69 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vstabile/politicos
# Tem 12 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/pydatamanaus/pydata-manaus
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wensttay/ourdata
# Tem 130 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dataprev/ckan-loader
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jacsonsantos/documentacao-aql-arangodb-pt-br
# Tem 10 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/br-lemes/atarefado
# Tem 138 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ocarneiro/dados-abertos-cd
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/datasum-analytics/open-data
# Tem 5 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/LegalHackersNatal/DadosAbertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/fbbergamo/Hackathon_Chutaum
# Tem 85 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/estados-brasileiros
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/paraibatransparente/dados
# Tem 95 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/CodeForCuritiba/Analises-Jupyter-Notebook
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/grstavares/DadosAbertosTSE
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucassouzamatos/projetos-ufsc
# Tem 42 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/pr-snas/nosmapas
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/msramos/lupa
# Tem 24 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/sergiosvieira/cerificados
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/fhpimenta/AviacaoOpenData
# Tem 14 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gabrielborgesdm/lunetagov
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rafaeldsouza/hhbres-controle-asma
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/aragonxpd154/SSH-Teste
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bi85/Mapa-de-Riscos-Barragens
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Falnesio/Time-Tito
# Tem 344 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/williamneto/intelectual
# Tem 78 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/germanoluz/infoviasbr
# Tem 41 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rodrigorgs/mergulhando-com-r
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/brunoqs/ckanext-ufla
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Revoada/dadosabertos
# Tem 37 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/DennyLoko/openalmg
# Tem 21 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/repo-CidadeAmarela
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/RamonGiovane/DadosAbertos
# Tem 14 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/EvaCosta/DadosAbertos
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucas000/PoliticoNaMao
# Tem 83 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/junior0160/DadosAbertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/FranciscoMMAlves/DadosAbertoss
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/MayaBrito/dadosAbertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/victorsfleite/Camara_DadosAbertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/darkbebs/pdi-DadosAbertos
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dfavato/ms_dados_abertos
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/luanoliveira1992/dadosBrasil
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vfgoncalves/DadosAbertosBrasil
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renvmorales/open-data-BR
# Tem 34 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Falnesio/Time-Tito
# Tem 344 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/williamneto/intelectual
# Tem 78 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/germanoluz/infoviasbr
# Tem 41 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rodrigorgs/mergulhando-com-r
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/brunoqs/ckanext-ufla
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Revoada/dadosabertos
# Tem 37 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/DennyLoko/openalmg
# Tem 21 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/repo-CidadeAmarela
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/RamonGiovane/DadosAbertos
# Tem 14 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/d116626/catalogo_dados
# Tem 14 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/EvaCosta/DadosAbertos
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucas000/PoliticoNaMao
# Tem 83 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/junior0160/DadosAbertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renato-bohler/mapa-dados-abertos
# Tem 49 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/FranciscoMMAlves/DadosAbertoss
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/MayaBrito/dadosAbertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/victorsfleite/Camara_DadosAbertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/darkbebs/pdi-DadosAbertos
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dfavato/ms_dados_abertos
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/luanoliveira1992/dadosBrasil
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vfgoncalves/DadosAbertosBrasil
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renvmorales/open-data-BR
# Tem 34 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bcbernardo/observatorio-niteroi
# Tem 22 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wellmsan/GetInepMicrodados
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/fbrissi/dados-abertos
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/BelianaCorreia123/DadosAbertosiMaps
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renatachagasc/Api-DadosAbertos-Eventos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/tie-dados-abertos/dadosAbertosSAMU
# Tem 10 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/karenazevedo/DadosAbertosDeputados
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/manoelpedroneto/enemviewer
# Tem 16 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/UlyssesRocha/DadosAbertosCD
# Tem 23 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/alexxdantass/DadosAbertosUFRN
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ccdpoa/ocida
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/ruifortes/opendata-pt
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/fmca/OpenCIn
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ulmi/dadosabertos_2017
# Tem 26 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/barragens-br
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gleidsonf/bens-tombados-mapa
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cmartins-ifpa/educ-br
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Kassio-Ferreira/perfil_racial_ufersa
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/gustavoem/balanco_municipal_tce
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jesuino/transportt-sjc-data
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lhvolso/ReclamacoesProcon
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Sidon/py-senador-br
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thiagonobrega/uepbOD
# Tem 58 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Panizzo/open-data
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ecalasans/tse_dados_abertos
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/davysouza/dados_abertos
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rapadurahacker/Dados-Abertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/eliasjcjunior/dados-abertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/idJoca/dados_abertos
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucaslamounier/dados_abertos
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/code-for-sao-paulo/dados-abertos
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/hugopsi/Dados-abertos
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/georgemaia/dadosabertos
# Tem 31 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/petersonjr/dados_abertos
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/transparencia-mg/blog-dados-abertos
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
# Tem 74 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/mhbsti/dados-abertos-curitiba
# Tem 28 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/natalialionel/Dados-Abertos-Desafios-e-Oportunidades
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/alexvlima/MTur-Dados-Turismo-por-UF
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thyall/Dados_UFRN
# Tem 23 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/dcarvalho/analise_dados_abertos
# Tem 7 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/comprasgovbr/API-dados-abertos
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/paulo-neto/visualizacaoDadosAbertos
# Tem 26 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Lorenaps/extrator-dados-abertos
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/filafb/dados-abertos-alesp
# Tem 76 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ptcampos/dados-abertos-graphql
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/baiana/Explorando-dados-abertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/pstwh/curitiba-dados-abertos-api
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/pedroboaron/ConsultaDadosAbertos
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gcianfarani/jogo-dados-abertos
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/ricardopoppi/Consulta-INDA
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jaraujouerj/Estruturas-de-Dados-Abertos
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vpcsilva/dados-abertos-cd
# Tem 15 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/henriquepgomide/dados-abertos-educacao
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucianosb/oficina-dados-abertos
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vitormd/dados_abertos_ruby
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
# Tem 30 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Lorenaps/dados-abertos-congresso
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/franklinmatheus/dados-abertos-ufrn
# Tem 12 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hugomsouto/mineracao-dados-abertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-shiny
# Tem 74 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/christiansurf10/dados-abertos-transparencia
# Tem 3 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/rafpyprog/Dados-Abertos-CNPJ
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leticiapontes/Angular-e-Dados-Abertos
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Kaentos/FundaoDadosAbertosTheme
# Tem 21 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/CaioSouzaGit/dados_abertos_ja
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/CaioSouzaGit/dados_abertos_ja
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/DINALVAGOMES/INSS_dados-abertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/rpcavaco/oficina_agueda_2017
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/eduponto21/dados_abertos_curitiba_disque_economia
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/luizmartins1980/apida
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/isaiasmelof/server-dados-abertos-camera
# Tem 34 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/naiieandrade/workshop-dados-abertos
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/matheusrocha89/deputados_app
# Tem 24 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/brunojardim/Cetus
# Tem 62 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/hducati/ceaps-data
# Tem 27 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leticiaverona/trabalhoesvravo
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/othoncampos/PublicDataScience
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/eduleones/github-scraper
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/salomaosilvasantos/trabalho_web_semantica
# Tem 17 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/altamir-bricks/whooshing-opendata
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/desireesantos/plataformaVisualizacao
# Tem 35 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/MarxSteel/MDIO-InteractBrasil
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/abelsiqueira/hackday14
# Tem 12 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/abjur/manifestos
# Tem 21 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/vilaralmeida/qualificajampa
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/yelken/livecity
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/J2MTecnologia/flisol_2014-open_data
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-website
# Tem 125 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/leo07vasp/geolocation
# Tem 3 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/josmarios/dac
# Tem 111 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/leoneljunior/DeOlhoNoPAC
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thiroc/projetoMOO
# Tem 16 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/setores-censitarios
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thenets/Warriors_OpenData
# Tem 25 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/eronsantosbetine/Projeto-CENIPA
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danilolimadutra/dados-abertos-governo
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/FelipeDeveloperFullStack/CamaraDosDeputados
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dgomesbr/playground-dados-gov-br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/patrickiarrocheski/analise_dados_cldf
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mmarossi/Atendimentos_Hosp_Brasilia
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leilton/PJIN
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/glauberramos/especiesameacadasrs
# Tem 22 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/matheuslrsouza/senadores
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/brunohgv/deputados-informacoes
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/matgonz/misogyny_on_twitter
# Tem 4 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/Kassio-Ferreira/perfil_racial
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Adailson-Jose/ouvidoria_df
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/kurka/handson-hackday-dados
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/bicicletas-compartilhadas
# Tem 29 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-process
# Tem 136 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/Yandson/transparencia-ma
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/observatoriosar/dataSANEAR
# Tem 16 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-search
# Tem 16 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-view
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-catalog
# Tem 47 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bozoh/meu-legislador
# Tem 25 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/marceloandriolli/dados_solarimetricos_brasil
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ggdrn/ClimMapView
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/crislanio/Dados_abertos_PortalDaTransparencia
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateushtoledo/sysvis
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/DeehSlash/EstruturaDeDadosHash
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danielCavalcanti553/angular-api-dados-iffar
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/georgemaia/dadosabertos-mobilidade-rn-natal
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/FabianoOLima/1_Dados-e-Cursos
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/canoi12/mineracao-dados-ufrn
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hicetnunc2000/Dados-Abertos-API-Camara-Python-Mining
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/alexaraujors/dadospoa_theme
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/marvinsiq/dados-procon
# Tem 90 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/planejamentoGovBr/siape-dadosabertos-ETL
# Tem 2 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/AndressaStefany/mineracao_docentes
# Tem 28 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/danielmbicalho/Dados_reposit-rios_e_ferramentas
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/xsolium360/transparencia-ma
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/CodeForCuritiba/ckan_curitiba
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/sjcdigital/eleicoes_abertas
# Tem 19 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/hirobs/cnj-bi
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jukabarros/denguezone-api
# Tem 36 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/macecchi/monografia-dcc
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hitalosiqueira/DAG
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/exercitando_pandas
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hdusantos/opencam
# Tem 41 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/Fabriciobarbosa/pesquisajupyter
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ProjetosDeBD-2018-2/tce-pe
# Tem 21 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/FrancinaldoCabral/projetocientifico
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/FABdadosabertos/EMAER
# Tem 2 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/posGraduacaoBancoDadosCefetMG2014/monografiaMineracaoDados
# Tem 4 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/atrfisch/api_camara
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/m88breu/delfoscwb
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/germanoluz/neways
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cassantana/web_scraping_Deputados
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dimascyriaco/camara
# Tem 51 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/sjcdigital/dashboard_financas
# Tem 1 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/FABdadosabertos/COMGEP
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/FABdadosabertos/GABAER
# Tem 52 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/EnriqueSampaio/dag-parser
# Tem 39 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/klismark/vigieSeuDeputado
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/AlbertoTrindade/RecifeConectado
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/relsi/congredata
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/anacarol91/wikiolap-interface
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/GadsDev/assembleia-mg-api
# Tem 36 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/turetos/appdadosabertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/febr-team/febr-book
# Tem 108 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wagner-goncalves/srcidadao-coletor-camara
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/richardbertozzo/projeto-data-mining
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Danielopes7/transparencia-ma
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/diegoep/rotasaude
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucasparreiras/OpenBHBUs
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Panizzo/transparencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/queriDO
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/KarolGranger/SenadoWS
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/narallynne/mineracao-ogd
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/prodest/dados.es.gov.br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danielCavalcanti553/angular-api-json-IFFAR
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rodrigosantana/Curso_R_Intro_UNIVALI_2015
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Danhfg/Analise-dos-Dados-Abertos-da-C-mara-de-Deputados
# Tem 21 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vtlg/angulegis
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/pboueke/ficha-espacial
# Tem 42 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/jjanuario/datamining
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wagner-goncalves/srcidadao-coletor-senado
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/desafio-camara
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/armandobs14/SaudeBR
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/oliveirabrunoa/ConsultaTempo
# Tem 3 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/tiagovizoto/OperacaoUniEsquina
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/kevenbmx/DYN_MST_BRSE
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/luiscape/congresso_aberto_viz
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/glauberferreira/exames-selecao-ifal
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucasknj/Projeto-Capstone
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Arnaldoeloi/discentes-ufrn-2009-2019-analise-dados
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/oxstormrider/vancrime
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/italo-batista/como-vota-deputado
# Tem 36 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/geovannyAvelar/Homicidios-dolosos-Sao-Paulo-2019
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/osamuelalmeid/Analise-Sobre-Acidentes-Aereos-no-Brasil
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/Dashboard
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/inacior/asteroids
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rodrigoferrazazevedo/ubs-rails
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/TCC
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/juliafealves/leda-tabela-hash-aberto
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/BrunoMoriB/stockmarket-manager
# Tem 23 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hiperorganicos/openlab_datavis
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/code-like-a-girl/hacker-cidadao-3.0
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/NastyaCodingBunny/PYTHON---SIMULADOR-DE-CADASTRO
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wharborges/analiseES
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/decosoares/diariasservidoresalagoas
# Tem 18911 Commits - 315 Contributors
#
# >>>  https://api.github.com/repos/leonardocouy/MaisCopa
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Idiego2/Dashboard-PHP-e-MySQL
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/OLIVEIRAFAEL/GoogleFinance
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/lodovikoa/convencao_financeiroapi
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/WelitonAmartins/Config-Redis-docker
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/AdemirSJRP/CSharp_BasicFramework
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bicudorafa/Projeto_R_WorldBankAPI_Analysis
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/AdemirSJRP/CSharp_BasicFramework
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renematos79/redis
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rafabrayner/importador_licitacoes_municipais_sagres
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Gabriellm2003/Coffee-CNN
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Pinalli/ibm-atm-challenge
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/warSantos/REDES02
# Tem 21 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/KassioVieira/starships
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ThomasMGuarnieri/GameReviewGender
# Tem 11 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/ronaldosampaio/testefrontend
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nathaliaSilva/PDFRelat-rios
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
# Tem 42 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
# Tem 40 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/mapaslivres/localidades
# Tem 69 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/brasilopen/brasilopen
# Tem 10 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
# Tem 49 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/paulozip/acidentes-aereos
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edumagol/Analise-Mapemaneto-Risco-Barragems-Brasil
# Tem 25 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/dados-abertos-gov-br
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Vnicius/dados-pb
# Tem 66 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ReciHub/Dados-Abertos-Recife
# Tem 12 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/marceloandriolli/informacao-salva
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/geovannyAvelar/Dados-Abertos-Campeonato-Brasileiro
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/ocarneiro/dados-abertos-cd
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/estados-brasileiros
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rafaeldsouza/hhbres-controle-asma
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bi85/Mapa-de-Riscos-Barragens
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/luanoliveira1992/dadosBrasil
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vfgoncalves/DadosAbertosBrasil
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/renvmorales/open-data-BR
# Tem 34 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/vgeorge/barragens-br
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cmartins-ifpa/educ-br
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mmarossi/Atendimentos_Hosp_Brasilia
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/MarxSteel/MDIO-InteractBrasil
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/marceloandriolli/dados_solarimetricos_brasil
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leticiaverona/trabalhoesvravo
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dgomesbr/playground-dados-gov-br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/FrancinaldoCabral/projetocientifico
# Tem 8 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/osamuelalmeid/Analise-Sobre-Acidentes-Aereos-no-Brasil
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/Dashboard
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/TCC
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
# Tem 159 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/dados-abertos-gov-br
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/peterleiva/CNES-API
# Tem 28 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/mariohmol/voos-fab
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucas000/PoliticoNaMao
# Tem 83 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/luanoliveira1992/dadosBrasil
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danilolimadutra/dados-abertos-governo
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/brunojardim/Cetus
# Tem 62 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
# Tem 74 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/prodest/dados.es.gov.br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateushtoledo/sysvis
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Panizzo/transparencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/desafio-camara
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/Dashboard
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/TCC
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
# Tem 42 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
# Tem 40 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/kerollaine/eaicongresso
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gabrielborgesdm/lunetagov
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leilton/PJIN
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/desireesantos/plataformaVisualizacao
# Tem 35 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
# Tem 30 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hitalosiqueira/DAG
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/diegoep/rotasaude
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/EnriqueSampaio/dag-parser
# Tem 39 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/narallynne/mineracao-ogd
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
# Tem 42 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
# Tem 40 Commits - 5 Contributors
#
# >>>  https://api.github.com/repos/kerollaine/eaicongresso
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/BrunnaMaiaradaSilva/Analise-de-Dados-Com-R
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/jpclarindo/IGOV
# Tem 3 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/bovino/cidprojetoaplicado
# Tem 35 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/rodrigosantosbr/catmat_compras_gov
# Tem 714 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gabrielborgesdm/lunetagov
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/geraldo7junior/-chega-
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leilton/PJIN
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/desireesantos/plataformaVisualizacao
# Tem 35 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
# Tem 30 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/diegoep/rotasaude
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/hitalosiqueira/DAG
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/EnriqueSampaio/dag-parser
# Tem 39 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/Jucojuco/midia_social
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/narallynne/mineracao-ogd
# Tem 3 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/rafaelodon/detector-fraudes-compras-gov
# Tem 50 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
# Tem 49 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/paraibatransparente/portal-symfony
# Tem 69 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/gilsondev/awesome-projects
# Tem 6 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/othoncampos/PublicDataScience
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Yandson/transparencia-ma
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/xsolium360/transparencia-ma
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/macecchi/monografia-dcc
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/AdemirSJRP/CSharp_BasicFramework
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/chapeupreto/sinesp
# Tem 39 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/sjcdigital/repasse-server
# Tem 401 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
# Tem 159 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/rennan/node-scrap-govbr
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cemsbr/dados.gov.br
# Tem 5 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/dados-abertos-gov-br
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/peterleiva/CNES-API
# Tem 28 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/analytics-ufcg/compras-gov
# Tem 23 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/claytonsilva/opendataday-es-2015
# Tem 20 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/mtrpires/raspafamilia
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/supermae/dashboard
# Tem 4 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/emilysoueu/transparencia-ma
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/afonsojota/seligabrasil
# Tem 12 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mariohmol/voos-fab
# Tem 17 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonlead/gastos-gov-federal
# Tem 25 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/M3nin0/scraping-bolsa-esmola
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/RobotsHoldingHands/Nome-Genero-Machine-Learning
# Tem 3 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/KarlaMembreno/Determinantes-da-Corrupcao-na-America-Latina-e-Caribe
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/netoferraz/people-analytics-gov
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/lucas000/PoliticoNaMao
# Tem 83 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/VictorDeon/DadosDoGoverno
# Tem 23 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/gabrielclages/study_pedaladasfiscais
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cvarda/transparencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/karenyov/dadosPoliticos
# Tem 5 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/luanoliveira1992/dadosBrasil
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mgaldino/gov_federal
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Macmod/PortalTransparenciaBR
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/dados.es.gov.br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Pantoja87/Big_Data_PySpark_Viagem
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/LuizPhelipe/Or-amento-Publico
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/guisaulo/IBD-PAC2
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danilolimadutra/dados-abertos-governo
# Tem 11 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/biigue/CancerData
# Tem 35 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/duarteguilherme/avaliacao_governo
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/brunojardim/Cetus
# Tem 62 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateushtoledo/sysvis
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/aldo2102/ELT-Pentaho-ClientRest-Com-Paginacao
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
# Tem 74 Commits - 3 Contributors
#
# >>>  https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/franciscogaluppo/Gastos-do-Governo-Federal
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/abevieiramota/dataset-gastos-diretos-federal
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Carrilh0/IncendiosEmUnidadesDeConservacaoFederais
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/joaofresende/ClassifDesclassif
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/paulohubert/resultado_primario
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Panizzo/transparencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/marcotmotta/ibd-query-project
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/antonivargas/desafio-camara
# Tem 13 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ces-jf/PSPA
# Tem 34 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/VitorRoque/Analise-Fila-o-Politica-BR
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/danielmarcelino/rRAIS
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nosdeedson/Projeto-leitura-de-API-com-Docker
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/chrmorais/scrapygdf
# Tem 6 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/Dashboard
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/beluzo/ideo
# Tem None Commits - None Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/TCC
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/enzoroiz/IBD-TP2
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/leobrj/camaraemfoco
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/VRPazdeJesus/multas-ibama
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/theuves/fddagudds
# Tem 30 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wiltomar/pySPED
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/wiltomar/jSPED
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Glautor/participe-db
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ValescaL/National-conferences-Conferencias-nacionais
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/sjcdigital/repasse-server
# Tem 401 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/campagnucci/dados-abertos-gov-br
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/analytics-ufcg/compras-gov
# Tem 23 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/KarlaMembreno/Determinantes-da-Corrupcao-na-America-Latina-e-Caribe
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/cvarda/transparencia
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mgaldino/gov_federal
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Pantoja87/Big_Data_PySpark_Viagem
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/paulohubert/resultado_primario
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/ces-jf/PSPA
# Tem 34 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/Dashboard
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/SabrinyBezerra/TCC
# Tem 47 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/BrunnaMaiaradaSilva/Analise-de-Dados-Com-R
# Tem 2 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/bovino/cidprojetoaplicado
# Tem 35 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/geraldo7junior/-chega-
# Tem 4 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonmottac/go-to-doc
# Tem 5 Commits - 0 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
# Tem 159 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/mtrpires/raspafamilia
# Tem 7 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/edsonlead/gastos-gov-federal
# Tem 25 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Macmod/PortalTransparenciaBR
# Tem 9 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/dados.es.gov.br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateushtoledo/sysvis
# Tem 3 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/nosdeedson/Projeto-leitura-de-API-com-Docker
# Tem 10 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/Glautor/participe-db
# Tem 15 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/kerollaine/eaicongresso
# Tem 19 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/NivSoft/transpy
# Tem 260 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
# Tem 159 Commits - 4 Contributors
#
# >>>  https://api.github.com/repos/thenets/ckanext-dadosabertos
# Tem 22 Commits - 2 Contributors
#
# >>>  https://api.github.com/repos/prodest/dados.es.gov.br
# Tem 1 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/prodest/ckanext-data_es_theme
# Tem 18 Commits - 1 Contributors
#
# >>>  https://api.github.com/repos/mateushtoledo/sysvis
# Tem 3 Commits - 1 Contributors
# CPU times: user 1min 11s, sys: 3.08 s, total: 1min 15s
# Wall time: 35min 45s

# %%
repositories_df.describe()
# Out:
#                id              full_name  \
# count         570                    570
# unique        404                    404
# top     195294598  edsonmottac/go-to-doc
# freq            6                      6
#
#                                               description owner_type  \
# count                                                 534        570
# unique                                                370          2
# top     Plugin/Tema do Portal de Dados Abertos do Gove...       User
# freq                                                    6        466
#
#                                   owner_api_url  \
# count                                       570
# unique                                      354
# top     https://api.github.com/users/dadosgovbr
# freq                                         16
#
#                             owner_url  \
# count                             570
# unique                            354
# top     https://github.com/dadosgovbr
# freq                               16
#
#                                              url  \
# count                                        570
# unique                                       404
# top     https://github.com/edsonmottac/go-to-doc
# freq                                           6
#
#                                                   api_url   fork  \
# count                                                 570    570
# unique                                                404      1
# top     https://api.github.com/repos/edsonmottac/go-to...  False
# freq                                                    6    570
#
#                   created_at      ...      language  has_issues  has_wiki  \
# count                    570      ...           424         570       570
# unique                   404      ...            22           2         2
# top     2017-08-23T19:05:48Z      ...        Python        True      True
# freq                       6      ...            92         555       553
#
#        forks_count forks open_issues  watchers  timestamp_extract  commits  \
# count          570   570         570       570                570      549
# unique          16    16          14        25                 28       83
# top              0     0           0         0         1573215966        1
# freq           424   424         488       395                 30       69
#
#         contributors
# count            549
# unique             9
# top                1
# freq             405
#
# [4 rows x 23 columns]

# %% [markdown]
# Conferindo valores nulos

# %%
repositories_df.loc[repositories_df['commits'].isnull()][['api_url', 'commits', 'contributors']]
# Out:
#                                                api_url commits contributors
# 146  https://api.github.com/repos/renatachagasc/Api...    None         None
# 152          https://api.github.com/repos/ccdpoa/ocida    None         None
# 159  https://api.github.com/repos/Kassio-Ferreira/p...    None         None
# 173  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 203  https://api.github.com/repos/hugomsouto/minera...    None         None
# 211  https://api.github.com/repos/DINALVAGOMES/INSS...    None         None
# 213  https://api.github.com/repos/eduponto21/dados_...    None         None
# 226  https://api.github.com/repos/MarxSteel/MDIO-In...    None         None
# 230       https://api.github.com/repos/yelken/livecity    None         None
# 276  https://api.github.com/repos/danielmbicalho/Da...    None         None
# 302  https://api.github.com/repos/klismark/vigieSeu...    None         None
# 307  https://api.github.com/repos/turetos/appdadosa...    None         None
# 330  https://api.github.com/repos/tiagovizoto/Opera...    None         None
# 332  https://api.github.com/repos/luiscape/congress...    None         None
# 350  https://api.github.com/repos/wharborges/analiseES    None         None
# 369  https://api.github.com/repos/nathaliaSilva/PDF...    None         None
# 393  https://api.github.com/repos/MarxSteel/MDIO-In...    None         None
# 415  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 510  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 515  https://api.github.com/repos/joaofresende/Clas...    None         None
# 527           https://api.github.com/repos/beluzo/ideo    None         None

# %%
repositories_df.loc[repositories_df['contributors'].isnull()][['api_url', 'commits', 'contributors']]
# Out:
#                                                api_url commits contributors
# 146  https://api.github.com/repos/renatachagasc/Api...    None         None
# 152          https://api.github.com/repos/ccdpoa/ocida    None         None
# 159  https://api.github.com/repos/Kassio-Ferreira/p...    None         None
# 173  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 203  https://api.github.com/repos/hugomsouto/minera...    None         None
# 211  https://api.github.com/repos/DINALVAGOMES/INSS...    None         None
# 213  https://api.github.com/repos/eduponto21/dados_...    None         None
# 226  https://api.github.com/repos/MarxSteel/MDIO-In...    None         None
# 230       https://api.github.com/repos/yelken/livecity    None         None
# 276  https://api.github.com/repos/danielmbicalho/Da...    None         None
# 302  https://api.github.com/repos/klismark/vigieSeu...    None         None
# 307  https://api.github.com/repos/turetos/appdadosa...    None         None
# 330  https://api.github.com/repos/tiagovizoto/Opera...    None         None
# 332  https://api.github.com/repos/luiscape/congress...    None         None
# 350  https://api.github.com/repos/wharborges/analiseES    None         None
# 369  https://api.github.com/repos/nathaliaSilva/PDF...    None         None
# 393  https://api.github.com/repos/MarxSteel/MDIO-In...    None         None
# 415  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 510  https://api.github.com/repos/GabrielLimaSnT/Pr...    None         None
# 515  https://api.github.com/repos/joaofresende/Clas...    None         None
# 527           https://api.github.com/repos/beluzo/ideo    None         None

# %%
file_path = '../data/repositories_' + str(time.time()).split('.')[0] + '.csv'
file_path
# Out:
# '../data/repositories_1573218408.csv'

# %%
repositories_df.to_csv(file_path, index=False)

# %% [markdown]
# ## Extraindo contribuidores dos repositórios

# %%
columns_contributors = [ 'repo_id',
                          'repo_name',
                          'repo_url',
                          'repo_api_url',
                          'contributor_id',
                          'contributor_login',
                          'contributor_type',
                          'contributor_url',
                          'contributor_api_url',
                          'timestamp_extract']

# %%
def scroll_results(results):
    
    list_contributors = []

    for result in results:
        contributor = {}
        
        contributor = {
            'contributor_id': result.get('id', None),
            'contributor_login': result.get('login', None),
            'contributor_type': result.get('type', None),
            'contributor_url': result.get('html_url', None),
            'contributor_api_url': result.get('url', None),
        }

        list_contributors.append(contributor)
        
    return list_contributors

# %%
def get_contributors(url):

    list_contributors = []
    results = requests.get(url, auth=credentials)
    
    # No caso do repositório estar vazio
    if results.status_code is 204:
        return None
    
    contributors_results = results.json()
    list_contributors = scroll_results(contributors_results)
    
    header = dict(results.links)
    
    while header.get('next', False):
        next_url = header.get('next').get('url')
        
        print('\t> Extraindo da próxima página: {0}'.format(next_url))
            
        results = requests.get(next_url, auth=credentials)
        contributors_results = results.json()
        list_contributors = list_contributors + scroll_results(contributors_results)    
        header = dict(results.links)
        
    return list_contributors

# %%
def add_contributor(repo, contributor):
            
    df = pd.DataFrame([[
                    repo.get('repo_id', None),
                    repo.get('repo_name', None),
                    repo.get('repo_url', None),      
                    repo.get('repo_api_url', None),
                    contributor.get('contributor_id', None),
                    contributor.get('contributor_login', None),
                    contributor.get('contributor_type', None),
                    contributor.get('contributor_url', None),
                    contributor.get('contributor_api_url', None),
                    str(time.time()).split('.')[0]]], columns=columns_contributors)

    return df

# %%
def save_contributors(contributors_df, repo, contributors):
    
    for contributor in contributors:
                
        contributors_df = pd.concat([contributors_df, 
                                     add_contributor(repo, contributor)], 
                                    ignore_index=True, 
                                    sort=False)
    return contributors_df

# %%
def search_contributors(repositories_df):
    
    contributors_df = pd.DataFrame(columns = columns_contributors)
    urls = repositories_df['api_url']
   
    for url in urls:
        print('\nExtraindo contribuidores de: {0}'.format(url))

        repo = {
            'repo_id': repositories_df.loc[repositories_df["api_url"] == url, 'id'].values[0],
            'repo_name': repositories_df.loc[repositories_df["api_url"] == url, 'full_name'].values[0],
            'repo_url': repositories_df.loc[repositories_df["api_url"] == url, 'url'].values[0],
            'repo_api_url': url,
        }
        
        url_contributors = url + '/contributors'        
        contributors = get_contributors(url_contributors)
        
        if contributors:
            contributors_df = save_contributors(contributors_df, repo, contributors)
        
    
    return contributors_df

# %%
# %%time
result_contributors = search_contributors(repositories_df)
# Out:
# Extraindo contribuidores de: https://api.github.com/repos/CamaraDosDeputados/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/prefeiturasp/dados-educacao
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/kit
#
# Extraindo contribuidores de: https://api.github.com/repos/mapaslivres/localidades
#
# Extraindo contribuidores de: https://api.github.com/repos/odufrn/odufrn-downloader
#
# Extraindo contribuidores de: https://api.github.com/repos/brasilopen/brasilopen
#
# Extraindo contribuidores de: https://api.github.com/repos/vitorbaptista/dados-abertos-camara.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/jonny-data/conheca-seu-vereador
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/processo-participacao-social-inda
#
# Extraindo contribuidores de: https://api.github.com/repos/npi-ufc-qxd/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/thefonseca/jogo-politico
#
# Extraindo contribuidores de: https://api.github.com/repos/zezente/opendata_aig_brazil
#
# Extraindo contribuidores de: https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/inepdadosabertos/api
#
# Extraindo contribuidores de: https://api.github.com/repos/sigalei/api-camara-graphql
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosabertosrn/DadosAbertosRN
#
# Extraindo contribuidores de: https://api.github.com/repos/paulozip/acidentes-aereos
#
# Extraindo contribuidores de: https://api.github.com/repos/codigourbano/ocorrencias-transito-pmsp
#
# Extraindo contribuidores de: https://api.github.com/repos/labhackercd/dados-abertos-2.0
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/api-siconv
#
# Extraindo contribuidores de: https://api.github.com/repos/transparenciahackday/dadosabertos.pt
#
# Extraindo contribuidores de: https://api.github.com/repos/edumagol/Analise-Mapemaneto-Risco-Barragems-Brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/abevieiramota/dataset-cnpj
#
# Extraindo contribuidores de: https://api.github.com/repos/ffknob/dados-abertos-elk
#
# Extraindo contribuidores de: https://api.github.com/repos/andreloc/open-data-assembleia-legislativa-ce
#
# Extraindo contribuidores de: https://api.github.com/repos/centraldedados/parlamento
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/Dados-Abertos-SJC
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/dados-abertos-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/danielmbicalho/Dados_repositorios_e_ferramentas
#
# Extraindo contribuidores de: https://api.github.com/repos/FABdadosabertos/CENIPA
#
# Extraindo contribuidores de: https://api.github.com/repos/luisleao/oicamara
#
# Extraindo contribuidores de: https://api.github.com/repos/anaschwendler/workshop-bahia
#
# Extraindo contribuidores de: https://api.github.com/repos/kerollaine/eaicongresso
#
# Extraindo contribuidores de: https://api.github.com/repos/code-for-joinville/joinville-opendata.github.io
#
# Extraindo contribuidores de: https://api.github.com/repos/tcm-ceara/apilayer
#
# Extraindo contribuidores de: https://api.github.com/repos/Vnicius/dados-pb
#
# Extraindo contribuidores de: https://api.github.com/repos/peterleiva/CNES-API
#
# Extraindo contribuidores de: https://api.github.com/repos/juliohenriquerocha/cidade-mapeada-lsi
#
# Extraindo contribuidores de: https://api.github.com/repos/Dayof/OpenData_BolsaFamilia
#
# Extraindo contribuidores de: https://api.github.com/repos/sergioamorim/lattes_mining
#
# Extraindo contribuidores de: https://api.github.com/repos/pyladiespb-org/minicurso-analise-descritiva-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/ReciHub/Dados-Abertos-Recife
#
# Extraindo contribuidores de: https://api.github.com/repos/isweluiz/verba_indenizatoria__cldf
#
# Extraindo contribuidores de: https://api.github.com/repos/alvarofpp/analise-ufrn-python-day-2018
#
# Extraindo contribuidores de: https://api.github.com/repos/mapaslivres/zonas-eleitorais
#
# Extraindo contribuidores de: https://api.github.com/repos/nilzao/cmspwiki
#
# Extraindo contribuidores de: https://api.github.com/repos/planejamentoGovBr/PDA-institucional-MP
#
# Extraindo contribuidores de: https://api.github.com/repos/okfn-brasil/gastos_abertos_dados
#
# Extraindo contribuidores de: https://api.github.com/repos/kheronn/transparencia-pr
#
# Extraindo contribuidores de: https://api.github.com/repos/nymarya/prf_api
#
# Extraindo contribuidores de: https://api.github.com/repos/marceloandriolli/informacao-salva
#
# Extraindo contribuidores de: https://api.github.com/repos/acvilarim/politicAPI
#
# Extraindo contribuidores de: https://api.github.com/repos/geovannyAvelar/Dados-Abertos-Campeonato-Brasileiro
#
# Extraindo contribuidores de: https://api.github.com/repos/GETIPUSP/dadosabertosnasaude
#
# Extraindo contribuidores de: https://api.github.com/repos/CodeForCuritiba/dadosabertos_prefs
#
# Extraindo contribuidores de: https://api.github.com/repos/djalmaaraujo/dadosabertos-cnpj-converter
#
# Extraindo contribuidores de: https://api.github.com/repos/nucleo-digital/sp-mapas
#
# Extraindo contribuidores de: https://api.github.com/repos/elciusferreira/propositions-analysis
#
# Extraindo contribuidores de: https://api.github.com/repos/mateusgrb/app-procon
#
# Extraindo contribuidores de: https://api.github.com/repos/thiagorondon/Deputando
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-package
#
# Extraindo contribuidores de: https://api.github.com/repos/culturagovbr/PDA-Sistema-MinC
#
# Extraindo contribuidores de: https://api.github.com/repos/tbai/opendata-br
#
# Extraindo contribuidores de: https://api.github.com/repos/neonlee/DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/Ermesoml/DadosAbertos-Vue
#
# Extraindo contribuidores de: https://api.github.com/repos/fmca/cinexplorer
#
# Extraindo contribuidores de: https://api.github.com/repos/interlegis/interlegis.portalmodelo.api
#
# Extraindo contribuidores de: https://api.github.com/repos/codigourbano/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/anp-qualidade/dados-abertos-pmqc
#
# Extraindo contribuidores de: https://api.github.com/repos/sergiohampel/hoteis-recife
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/wseidel/serveoquantoganha
#
# Extraindo contribuidores de: https://api.github.com/repos/paraibatransparente/portal-symfony
#
# Extraindo contribuidores de: https://api.github.com/repos/vstabile/politicos
#
# Extraindo contribuidores de: https://api.github.com/repos/pydatamanaus/pydata-manaus
#
# Extraindo contribuidores de: https://api.github.com/repos/wensttay/ourdata
#
# Extraindo contribuidores de: https://api.github.com/repos/dataprev/ckan-loader
#
# Extraindo contribuidores de: https://api.github.com/repos/jacsonsantos/documentacao-aql-arangodb-pt-br
#
# Extraindo contribuidores de: https://api.github.com/repos/br-lemes/atarefado
#
# Extraindo contribuidores de: https://api.github.com/repos/ocarneiro/dados-abertos-cd
#
# Extraindo contribuidores de: https://api.github.com/repos/datasum-analytics/open-data
#
# Extraindo contribuidores de: https://api.github.com/repos/LegalHackersNatal/DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/fbbergamo/Hackathon_Chutaum
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/estados-brasileiros
#
# Extraindo contribuidores de: https://api.github.com/repos/paraibatransparente/dados
#
# Extraindo contribuidores de: https://api.github.com/repos/CodeForCuritiba/Analises-Jupyter-Notebook
#
# Extraindo contribuidores de: https://api.github.com/repos/grstavares/DadosAbertosTSE
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-data
#
# Extraindo contribuidores de: https://api.github.com/repos/brunousml/Maquiavel
#
# Extraindo contribuidores de: https://api.github.com/repos/chris-redfield/open-up-with-simplicity
# Extraindo contribuidores de: https://api.github.com/repos/fredbortolato/dados-abertos-alesp
#
# Extraindo contribuidores de: https://api.github.com/repos/erickos/Case_BibliotecaUFRN_DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/Ermesoml/Dados-Abertos-Camara-Legislativa
#
# Extraindo contribuidores de: https://api.github.com/repos/pbaesse/plataforma-livre-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/paulochf/anp-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/PlanoDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/CodeForCuritiba/ds_curitiba_dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/codigourbano/distritos-sp
#
# Extraindo contribuidores de: https://api.github.com/repos/dfalbel/cota-parlamentar
#
# Extraindo contribuidores de: https://api.github.com/repos/MarcosTrajano/ionicTabelaFipe
#
# Extraindo contribuidores de: https://api.github.com/repos/matheusjacobina/Raspagem-Proposicoes-Camara
#
# Extraindo contribuidores de: https://api.github.com/repos/gilsondev/awesome-projects
#
# Extraindo contribuidores de: https://api.github.com/repos/mariohmol/voos-fab
#
# Extraindo contribuidores de: https://api.github.com/repos/vilaralmeida/cargaANS
#
# Extraindo contribuidores de: https://api.github.com/repos/paraibatransparente/salarios-servidores
#
# Extraindo contribuidores de: https://api.github.com/repos/ocefpaf/2019-10-27-PyBr-talk
#
# Extraindo contribuidores de: https://api.github.com/repos/lucassouzamatos/projetos-ufsc
#
# Extraindo contribuidores de: https://api.github.com/repos/pr-snas/nosmapas
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-validacao
#
# Extraindo contribuidores de: https://api.github.com/repos/msramos/lupa
#
# Extraindo contribuidores de: https://api.github.com/repos/sergiosvieira/cerificados
#
# Extraindo contribuidores de: https://api.github.com/repos/fhpimenta/AviacaoOpenData
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
#
# Extraindo contribuidores de: https://api.github.com/repos/gabrielborgesdm/lunetagov
#
# Extraindo contribuidores de: https://api.github.com/repos/rafaeldsouza/hhbres-controle-asma
#
# Extraindo contribuidores de: https://api.github.com/repos/aragonxpd154/SSH-Teste
#
# Extraindo contribuidores de: https://api.github.com/repos/bi85/Mapa-de-Riscos-Barragens
#
# Extraindo contribuidores de: https://api.github.com/repos/Falnesio/Time-Tito
#
# Extraindo contribuidores de: https://api.github.com/repos/williamneto/intelectual
#
# Extraindo contribuidores de: https://api.github.com/repos/germanoluz/infoviasbr
#
# Extraindo contribuidores de: https://api.github.com/repos/rodrigorgs/mergulhando-com-r
#
# Extraindo contribuidores de: https://api.github.com/repos/brunoqs/ckanext-ufla
#
# Extraindo contribuidores de: https://api.github.com/repos/Revoada/dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/ppKrauss/repo-CidadeAmarela
#
# Extraindo contribuidores de: https://api.github.com/repos/DennyLoko/openalmg
#
# Extraindo contribuidores de: https://api.github.com/repos/RamonGiovane/DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/d116626/catalogo_dados
#
# Extraindo contribuidores de: https://api.github.com/repos/EvaCosta/DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/lucas000/PoliticoNaMao
#
# Extraindo contribuidores de: https://api.github.com/repos/junior0160/DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/renato-bohler/mapa-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/FranciscoMMAlves/DadosAbertoss
#
# Extraindo contribuidores de: https://api.github.com/repos/MayaBrito/dadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/victorsfleite/Camara_DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/darkbebs/pdi-DadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/dfavato/ms_dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/luanoliveira1992/dadosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/vfgoncalves/DadosAbertosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/renvmorales/open-data-BR
#
# Extraindo contribuidores de: https://api.github.com/repos/bcbernardo/observatorio-niteroi
#
# Extraindo contribuidores de: https://api.github.com/repos/wellmsan/GetInepMicrodados
#
# Extraindo contribuidores de: https://api.github.com/repos/renatachagasc/Api-DadosAbertos-Eventos
#
# Extraindo contribuidores de: https://api.github.com/repos/tie-dados-abertos/dadosAbertosSAMU
#
# Extraindo contribuidores de: https://api.github.com/repos/BelianaCorreia123/DadosAbertosiMaps
#
# Extraindo contribuidores de: https://api.github.com/repos/karenazevedo/DadosAbertosDeputados
#
# Extraindo contribuidores de: https://api.github.com/repos/fbrissi/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/manoelpedroneto/enemviewer
#
# Extraindo contribuidores de: https://api.github.com/repos/UlyssesRocha/DadosAbertosCD
#
# Extraindo contribuidores de: https://api.github.com/repos/alexxdantass/DadosAbertosUFRN
#
# Extraindo contribuidores de: https://api.github.com/repos/ccdpoa/ocida
#
# Extraindo contribuidores de: https://api.github.com/repos/ruifortes/opendata-pt
#
# Extraindo contribuidores de: https://api.github.com/repos/fmca/OpenCIn
#
# Extraindo contribuidores de: https://api.github.com/repos/ulmi/dadosabertos_2017
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/barragens-br
#
# Extraindo contribuidores de: https://api.github.com/repos/gleidsonf/bens-tombados-mapa
#
# Extraindo contribuidores de: https://api.github.com/repos/cmartins-ifpa/educ-br
#
# Extraindo contribuidores de: https://api.github.com/repos/Kassio-Ferreira/perfil_racial_ufersa
#
# Extraindo contribuidores de: https://api.github.com/repos/gustavoem/balanco_municipal_tce
#
# Extraindo contribuidores de: https://api.github.com/repos/jesuino/transportt-sjc-data
#
# Extraindo contribuidores de: https://api.github.com/repos/lhvolso/ReclamacoesProcon
#
# Extraindo contribuidores de: https://api.github.com/repos/Sidon/py-senador-br
#
# Extraindo contribuidores de: https://api.github.com/repos/thiagonobrega/uepbOD
#
# Extraindo contribuidores de: https://api.github.com/repos/Panizzo/open-data
#
# Extraindo contribuidores de: https://api.github.com/repos/ecalasans/tse_dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/davysouza/dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/eliasjcjunior/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/idJoca/dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/rapadurahacker/Dados-Abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/code-for-sao-paulo/dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/lucaslamounier/dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/hugopsi/Dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/georgemaia/dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/petersonjr/dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
#
# Extraindo contribuidores de: https://api.github.com/repos/natalialionel/Dados-Abertos-Desafios-e-Oportunidades
#
# Extraindo contribuidores de: https://api.github.com/repos/mhbsti/dados-abertos-curitiba
#
# Extraindo contribuidores de: https://api.github.com/repos/transparencia-mg/blog-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/alexvlima/MTur-Dados-Turismo-por-UF
#
# Extraindo contribuidores de: https://api.github.com/repos/thyall/Dados_UFRN
#
# Extraindo contribuidores de: https://api.github.com/repos/dcarvalho/analise_dados_abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/comprasgovbr/API-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/paulo-neto/visualizacaoDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/Lorenaps/extrator-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/filafb/dados-abertos-alesp
# Extraindo contribuidores de: https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/ptcampos/dados-abertos-graphql
#
# Extraindo contribuidores de: https://api.github.com/repos/henriquepgomide/dados-abertos-educacao
#
# Extraindo contribuidores de: https://api.github.com/repos/baiana/Explorando-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/pedroboaron/ConsultaDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/pstwh/curitiba-dados-abertos-api
#
# Extraindo contribuidores de: https://api.github.com/repos/gcianfarani/jogo-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/jaraujouerj/Estruturas-de-Dados-Abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/ricardopoppi/Consulta-INDA
#
# Extraindo contribuidores de: https://api.github.com/repos/vpcsilva/dados-abertos-cd
#
# Extraindo contribuidores de: https://api.github.com/repos/franklinmatheus/dados-abertos-ufrn
#
# Extraindo contribuidores de: https://api.github.com/repos/Lorenaps/dados-abertos-congresso
#
# Extraindo contribuidores de: https://api.github.com/repos/hugomsouto/mineracao-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/lucianosb/oficina-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/RCristiano/scrapy_dados_abertos_cnpj
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-shiny
#
# Extraindo contribuidores de: https://api.github.com/repos/vitormd/dados_abertos_ruby
#
# Extraindo contribuidores de: https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/CaioSouzaGit/dados_abertos_ja
#
# Extraindo contribuidores de: https://api.github.com/repos/Kaentos/FundaoDadosAbertosTheme
#
# Extraindo contribuidores de: https://api.github.com/repos/DINALVAGOMES/INSS_dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/christiansurf10/dados-abertos-transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/rpcavaco/oficina_agueda_2017
#
# Extraindo contribuidores de: https://api.github.com/repos/luizmartins1980/apida
#
# Extraindo contribuidores de: https://api.github.com/repos/eduponto21/dados_abertos_curitiba_disque_economia
#
# Extraindo contribuidores de: https://api.github.com/repos/hducati/ceaps-data
#
# Extraindo contribuidores de: https://api.github.com/repos/matheusrocha89/deputados_app
#
# Extraindo contribuidores de: https://api.github.com/repos/brunojardim/Cetus
#
# Extraindo contribuidores de: https://api.github.com/repos/leticiaverona/trabalhoesvravo
#
# Extraindo contribuidores de: https://api.github.com/repos/othoncampos/PublicDataScience
#
# Extraindo contribuidores de: https://api.github.com/repos/eduleones/github-scraper
#
# Extraindo contribuidores de: https://api.github.com/repos/salomaosilvasantos/trabalho_web_semantica
#
# Extraindo contribuidores de: https://api.github.com/repos/altamir-bricks/whooshing-opendata
#
# Extraindo contribuidores de: https://api.github.com/repos/desireesantos/plataformaVisualizacao
#
# Extraindo contribuidores de: https://api.github.com/repos/abelsiqueira/hackday14
#
# Extraindo contribuidores de: https://api.github.com/repos/MarxSteel/MDIO-InteractBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/abjur/manifestos
#
# Extraindo contribuidores de: https://api.github.com/repos/vilaralmeida/qualificajampa
#
# Extraindo contribuidores de: https://api.github.com/repos/yelken/livecity
#
# Extraindo contribuidores de: https://api.github.com/repos/J2MTecnologia/flisol_2014-open_data
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-website
#
# Extraindo contribuidores de: https://api.github.com/repos/josmarios/dac
#
# Extraindo contribuidores de: https://api.github.com/repos/leo07vasp/geolocation
#
# Extraindo contribuidores de: https://api.github.com/repos/danilolimadutra/dados-abertos-governo
#
# Extraindo contribuidores de: https://api.github.com/repos/leoneljunior/DeOlhoNoPAC
#
# Extraindo contribuidores de: https://api.github.com/repos/thiroc/projetoMOO
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/setores-censitarios
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/Warriors_OpenData
#
# Extraindo contribuidores de: https://api.github.com/repos/eronsantosbetine/Projeto-CENIPA
#
# Extraindo contribuidores de: https://api.github.com/repos/FelipeDeveloperFullStack/CamaraDosDeputados
#
# Extraindo contribuidores de: https://api.github.com/repos/matheuslrsouza/senadores
#
# Extraindo contribuidores de: https://api.github.com/repos/glauberramos/especiesameacadasrs
#
# Extraindo contribuidores de: https://api.github.com/repos/danilolimadutra/dados-abertos-governo
#
# Extraindo contribuidores de: https://api.github.com/repos/FelipeDeveloperFullStack/CamaraDosDeputados
#
# Extraindo contribuidores de: https://api.github.com/repos/leilton/PJIN
#
# Extraindo contribuidores de: https://api.github.com/repos/glauberramos/especiesameacadasrs
#
# Extraindo contribuidores de: https://api.github.com/repos/matheuslrsouza/senadores
#
# Extraindo contribuidores de: https://api.github.com/repos/brunohgv/deputados-informacoes
#
# Extraindo contribuidores de: https://api.github.com/repos/dgomesbr/playground-dados-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/patrickiarrocheski/analise_dados_cldf
#
# Extraindo contribuidores de: https://api.github.com/repos/mmarossi/Atendimentos_Hosp_Brasilia
#
# Extraindo contribuidores de: https://api.github.com/repos/matgonz/misogyny_on_twitter
#
# Extraindo contribuidores de: https://api.github.com/repos/Kassio-Ferreira/perfil_racial
#
# Extraindo contribuidores de: https://api.github.com/repos/Adailson-Jose/ouvidoria_df
#
# Extraindo contribuidores de: https://api.github.com/repos/kurka/handson-hackday-dados
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/bicicletas-compartilhadas
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-process
#
# Extraindo contribuidores de: https://api.github.com/repos/Yandson/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/observatoriosar/dataSANEAR
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-search
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-view
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-catalog
#
# Extraindo contribuidores de: https://api.github.com/repos/bozoh/meu-legislador
#
# Extraindo contribuidores de: https://api.github.com/repos/marceloandriolli/dados_solarimetricos_brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/ggdrn/ClimMapView
#
# Extraindo contribuidores de: https://api.github.com/repos/crislanio/Dados_abertos_PortalDaTransparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
#
# Extraindo contribuidores de: https://api.github.com/repos/mateushtoledo/sysvis
#
# Extraindo contribuidores de: https://api.github.com/repos/DeehSlash/EstruturaDeDadosHash
#
# Extraindo contribuidores de: https://api.github.com/repos/danielCavalcanti553/angular-api-dados-iffar
#
# Extraindo contribuidores de: https://api.github.com/repos/georgemaia/dadosabertos-mobilidade-rn-natal
#
# Extraindo contribuidores de: https://api.github.com/repos/FabianoOLima/1_Dados-e-Cursos
#
# Extraindo contribuidores de: https://api.github.com/repos/canoi12/mineracao-dados-ufrn
#
# Extraindo contribuidores de: https://api.github.com/repos/hicetnunc2000/Dados-Abertos-API-Camara-Python-Mining
#
# Extraindo contribuidores de: https://api.github.com/repos/alexaraujors/dadospoa_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/marvinsiq/dados-procon
#
# Extraindo contribuidores de: https://api.github.com/repos/planejamentoGovBr/siape-dadosabertos-ETL
#
# Extraindo contribuidores de: https://api.github.com/repos/AndressaStefany/mineracao_docentes
#
# Extraindo contribuidores de: https://api.github.com/repos/danielmbicalho/Dados_reposit-rios_e_ferramentas
#
# Extraindo contribuidores de: https://api.github.com/repos/xsolium360/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/eleicoes_abertas
#
# Extraindo contribuidores de: https://api.github.com/repos/CodeForCuritiba/ckan_curitiba
# Extraindo contribuidores de: https://api.github.com/repos/hirobs/cnj-bi
#
# Extraindo contribuidores de: https://api.github.com/repos/FrancinaldoCabral/projetocientifico
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/FABdadosabertos/EMAER
#
# Extraindo contribuidores de: https://api.github.com/repos/macecchi/monografia-dcc
#
# Extraindo contribuidores de: https://api.github.com/repos/hitalosiqueira/DAG
#
# Extraindo contribuidores de: https://api.github.com/repos/jukabarros/denguezone-api
#
# Extraindo contribuidores de: https://api.github.com/repos/ProjetosDeBD-2018-2/tce-pe
#
# Extraindo contribuidores de: https://api.github.com/repos/Fabriciobarbosa/pesquisajupyter
#
# Extraindo contribuidores de: https://api.github.com/repos/hdusantos/opencam
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/exercitando_pandas
#
# Extraindo contribuidores de: https://api.github.com/repos/posGraduacaoBancoDadosCefetMG2014/monografiaMineracaoDados
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonmottac/go-to-doc
#
# Extraindo contribuidores de: https://api.github.com/repos/atrfisch/api_camara
#
# Extraindo contribuidores de: https://api.github.com/repos/dimascyriaco/camara
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/dashboard_financas
#
# Extraindo contribuidores de: https://api.github.com/repos/FABdadosabertos/COMGEP
#
# Extraindo contribuidores de: https://api.github.com/repos/FABdadosabertos/GABAER
#
# Extraindo contribuidores de: https://api.github.com/repos/germanoluz/neways
#
# Extraindo contribuidores de: https://api.github.com/repos/cassantana/web_scraping_Deputados
#
# Extraindo contribuidores de: https://api.github.com/repos/m88breu/delfoscwb
#
# Extraindo contribuidores de: https://api.github.com/repos/EnriqueSampaio/dag-parser
#
# Extraindo contribuidores de: https://api.github.com/repos/klismark/vigieSeuDeputado
#
# Extraindo contribuidores de: https://api.github.com/repos/AlbertoTrindade/RecifeConectado
#
# Extraindo contribuidores de: https://api.github.com/repos/relsi/congredata
#
# Extraindo contribuidores de: https://api.github.com/repos/anacarol91/wikiolap-interface
#
# Extraindo contribuidores de: https://api.github.com/repos/GadsDev/assembleia-mg-api
#
# Extraindo contribuidores de: https://api.github.com/repos/turetos/appdadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/febr-team/febr-book
#
# Extraindo contribuidores de: https://api.github.com/repos/richardbertozzo/projeto-data-mining
#
# Extraindo contribuidores de: https://api.github.com/repos/wagner-goncalves/srcidadao-coletor-camara
#
# Extraindo contribuidores de: https://api.github.com/repos/Danielopes7/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/diegoep/rotasaude
#
# Extraindo contribuidores de: https://api.github.com/repos/Panizzo/transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/lucasparreiras/OpenBHBUs
#
# Extraindo contribuidores de: https://api.github.com/repos/ppKrauss/queriDO
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
#
# Extraindo contribuidores de: https://api.github.com/repos/KarolGranger/SenadoWS
#
# Extraindo contribuidores de: https://api.github.com/repos/narallynne/mineracao-ogd
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/dados.es.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/danielCavalcanti553/angular-api-json-IFFAR
#
# Extraindo contribuidores de: https://api.github.com/repos/rodrigosantana/Curso_R_Intro_UNIVALI_2015
#
# Extraindo contribuidores de: https://api.github.com/repos/Danhfg/Analise-dos-Dados-Abertos-da-C-mara-de-Deputados
#
# Extraindo contribuidores de: https://api.github.com/repos/vtlg/angulegis
#
# Extraindo contribuidores de: https://api.github.com/repos/pboueke/ficha-espacial
#
# Extraindo contribuidores de: https://api.github.com/repos/jjanuario/datamining
#
# Extraindo contribuidores de: https://api.github.com/repos/wagner-goncalves/srcidadao-coletor-senado
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/desafio-camara
#
# Extraindo contribuidores de: https://api.github.com/repos/armandobs14/SaudeBR
#
# Extraindo contribuidores de: https://api.github.com/repos/oliveirabrunoa/ConsultaTempo
#
# Extraindo contribuidores de: https://api.github.com/repos/tiagovizoto/OperacaoUniEsquina
#
# Extraindo contribuidores de: https://api.github.com/repos/kevenbmx/DYN_MST_BRSE
#
# Extraindo contribuidores de: https://api.github.com/repos/luiscape/congresso_aberto_viz
#
# Extraindo contribuidores de: https://api.github.com/repos/glauberferreira/exames-selecao-ifal
#
# Extraindo contribuidores de: https://api.github.com/repos/lucasknj/Projeto-Capstone
#
# Extraindo contribuidores de: https://api.github.com/repos/Arnaldoeloi/discentes-ufrn-2009-2019-analise-dados
#
# Extraindo contribuidores de: https://api.github.com/repos/oxstormrider/vancrime
#
# Extraindo contribuidores de: https://api.github.com/repos/italo-batista/como-vota-deputado
#
# Extraindo contribuidores de: https://api.github.com/repos/geovannyAvelar/Homicidios-dolosos-Sao-Paulo-2019
#
# Extraindo contribuidores de: https://api.github.com/repos/osamuelalmeid/Analise-Sobre-Acidentes-Aereos-no-Brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/Dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/inacior/asteroids
#
# Extraindo contribuidores de: https://api.github.com/repos/rodrigoferrazazevedo/ubs-rails
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/TCC
#
# Extraindo contribuidores de: https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
#
# Extraindo contribuidores de: https://api.github.com/repos/juliafealves/leda-tabela-hash-aberto
#
# Extraindo contribuidores de: https://api.github.com/repos/BrunoMoriB/stockmarket-manager
#
# Extraindo contribuidores de: https://api.github.com/repos/hiperorganicos/openlab_datavis
#
# Extraindo contribuidores de: https://api.github.com/repos/code-like-a-girl/hacker-cidadao-3.0
#
# Extraindo contribuidores de: https://api.github.com/repos/NastyaCodingBunny/PYTHON---SIMULADOR-DE-CADASTRO
#
# Extraindo contribuidores de: https://api.github.com/repos/wharborges/analiseES
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama
#
# Extraindo contribuidores de: https://api.github.com/repos/decosoares/diariasservidoresalagoas
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=2
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=3
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=4
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=5
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=6
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=7
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=8
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=9
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=10
# 	> Extraindo da próxima página: https://api.github.com/repositories/86646585/contributors?page=11
#
# Extraindo contribuidores de: https://api.github.com/repos/leonardocouy/MaisCopa
#
# Extraindo contribuidores de: https://api.github.com/repos/Idiego2/Dashboard-PHP-e-MySQL
#
# Extraindo contribuidores de: https://api.github.com/repos/OLIVEIRAFAEL/GoogleFinance
#
# Extraindo contribuidores de: https://api.github.com/repos/lodovikoa/convencao_financeiroapi
#
# Extraindo contribuidores de: https://api.github.com/repos/WelitonAmartins/Config-Redis-docker
#
# Extraindo contribuidores de: https://api.github.com/repos/AdemirSJRP/CSharp_BasicFramework
#
# Extraindo contribuidores de: https://api.github.com/repos/bicudorafa/Projeto_R_WorldBankAPI_Analysis
#
# Extraindo contribuidores de: https://api.github.com/repos/rafaelimai/rbmc_batch_proc
#
# Extraindo contribuidores de: https://api.github.com/repos/renematos79/redis
# Extraindo contribuidores de: https://api.github.com/repos/rafabrayner/importador_licitacoes_municipais_sagres
#
# Extraindo contribuidores de: https://api.github.com/repos/Gabriellm2003/Coffee-CNN
#
# Extraindo contribuidores de: https://api.github.com/repos/Pinalli/ibm-atm-challenge
#
# Extraindo contribuidores de: https://api.github.com/repos/warSantos/REDES02
#
# Extraindo contribuidores de: https://api.github.com/repos/KassioVieira/starships
#
# Extraindo contribuidores de: https://api.github.com/repos/ThomasMGuarnieri/GameReviewGender
#
# Extraindo contribuidores de: https://api.github.com/repos/ronaldosampaio/testefrontend
#
# Extraindo contribuidores de: https://api.github.com/repos/nathaliaSilva/PDFRelat-rios
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/mapaslivres/localidades
#
# Extraindo contribuidores de: https://api.github.com/repos/brasilopen/brasilopen
#
# Extraindo contribuidores de: https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/paulozip/acidentes-aereos
#
# Extraindo contribuidores de: https://api.github.com/repos/edumagol/Analise-Mapemaneto-Risco-Barragems-Brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/dados-abertos-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/Vnicius/dados-pb
#
# Extraindo contribuidores de: https://api.github.com/repos/ReciHub/Dados-Abertos-Recife
#
# Extraindo contribuidores de: https://api.github.com/repos/marceloandriolli/informacao-salva
#
# Extraindo contribuidores de: https://api.github.com/repos/geovannyAvelar/Dados-Abertos-Campeonato-Brasileiro
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/ocarneiro/dados-abertos-cd
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/estados-brasileiros
#
# Extraindo contribuidores de: https://api.github.com/repos/rafaeldsouza/hhbres-controle-asma
#
# Extraindo contribuidores de: https://api.github.com/repos/bi85/Mapa-de-Riscos-Barragens
#
# Extraindo contribuidores de: https://api.github.com/repos/luanoliveira1992/dadosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/vfgoncalves/DadosAbertosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/renvmorales/open-data-BR
#
# Extraindo contribuidores de: https://api.github.com/repos/vgeorge/barragens-br
#
# Extraindo contribuidores de: https://api.github.com/repos/cmartins-ifpa/educ-br
#
# Extraindo contribuidores de: https://api.github.com/repos/mmarossi/Atendimentos_Hosp_Brasilia
#
# Extraindo contribuidores de: https://api.github.com/repos/MarxSteel/MDIO-InteractBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/marceloandriolli/dados_solarimetricos_brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/leticiaverona/trabalhoesvravo
#
# Extraindo contribuidores de: https://api.github.com/repos/dgomesbr/playground-dados-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/FrancinaldoCabral/projetocientifico
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonmottac/go-to-doc
#
# Extraindo contribuidores de: https://api.github.com/repos/klismark/vigieSeuDeputado
#
# Extraindo contribuidores de: https://api.github.com/repos/osamuelalmeid/Analise-Sobre-Acidentes-Aereos-no-Brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/Dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/TCC
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/dados-abertos-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/peterleiva/CNES-API
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/mariohmol/voos-fab
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
#
# Extraindo contribuidores de: https://api.github.com/repos/lucas000/PoliticoNaMao
#
# Extraindo contribuidores de: https://api.github.com/repos/luanoliveira1992/dadosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/danilolimadutra/dados-abertos-governo
#
# Extraindo contribuidores de: https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/brunojardim/Cetus
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/dados.es.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/mateushtoledo/sysvis
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
#
# Extraindo contribuidores de: https://api.github.com/repos/Panizzo/transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/desafio-camara
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/Dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/TCC
#
# Extraindo contribuidores de: https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/kerollaine/eaicongresso
#
# Extraindo contribuidores de: https://api.github.com/repos/gabrielborgesdm/lunetagov
#
# Extraindo contribuidores de: https://api.github.com/repos/leilton/PJIN
#
# Extraindo contribuidores de: https://api.github.com/repos/desireesantos/plataformaVisualizacao
#
# Extraindo contribuidores de: https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/diegoep/rotasaude
#
# Extraindo contribuidores de: https://api.github.com/repos/EnriqueSampaio/dag-parser
#
# Extraindo contribuidores de: https://api.github.com/repos/hitalosiqueira/DAG
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonmottac/go-to-doc
#
# Extraindo contribuidores de: https://api.github.com/repos/narallynne/mineracao-ogd
#
# Extraindo contribuidores de: https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/catalogos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/aplicativos-dados-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/kerollaine/eaicongresso
#
# Extraindo contribuidores de: https://api.github.com/repos/BrunnaMaiaradaSilva/Analise-de-Dados-Com-R
#
# Extraindo contribuidores de: https://api.github.com/repos/jpclarindo/IGOV
#
# Extraindo contribuidores de: https://api.github.com/repos/bovino/cidprojetoaplicado
#
# Extraindo contribuidores de: https://api.github.com/repos/rodrigosantosbr/catmat_compras_gov
#
# Extraindo contribuidores de: https://api.github.com/repos/gabrielborgesdm/lunetagov
#
# Extraindo contribuidores de: https://api.github.com/repos/geraldo7junior/-chega-
#
# Extraindo contribuidores de: https://api.github.com/repos/leilton/PJIN
#
# Extraindo contribuidores de: https://api.github.com/repos/desireesantos/plataformaVisualizacao
#
# Extraindo contribuidores de: https://api.github.com/repos/Lorenaps/caracterizacao-ds-dados-abertos
#
# Extraindo contribuidores de: https://api.github.com/repos/diegoep/rotasaude
#
# Extraindo contribuidores de: https://api.github.com/repos/EnriqueSampaio/dag-parser
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonmottac/go-to-doc
# Extraindo contribuidores de: https://api.github.com/repos/Jucojuco/midia_social
#
# Extraindo contribuidores de: https://api.github.com/repos/hitalosiqueira/DAG
#
# Extraindo contribuidores de: https://api.github.com/repos/narallynne/mineracao-ogd
#
# Extraindo contribuidores de: https://api.github.com/repos/rafaelodon/detector-fraudes-compras-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
#
# Extraindo contribuidores de: https://api.github.com/repos/augusto-herrmann/transparencia-dados-abertos-brasil
#
# Extraindo contribuidores de: https://api.github.com/repos/paraibatransparente/portal-symfony
#
# Extraindo contribuidores de: https://api.github.com/repos/gilsondev/awesome-projects
#
# Extraindo contribuidores de: https://api.github.com/repos/othoncampos/PublicDataScience
#
# Extraindo contribuidores de: https://api.github.com/repos/Yandson/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/xsolium360/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/macecchi/monografia-dcc
#
# Extraindo contribuidores de: https://api.github.com/repos/AdemirSJRP/CSharp_BasicFramework
#
# Extraindo contribuidores de: https://api.github.com/repos/chapeupreto/sinesp
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/repasse-server
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
#
# Extraindo contribuidores de: https://api.github.com/repos/rennan/node-scrap-govbr
#
# Extraindo contribuidores de: https://api.github.com/repos/cemsbr/dados.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/dados-abertos-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/peterleiva/CNES-API
#
# Extraindo contribuidores de: https://api.github.com/repos/analytics-ufcg/compras-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/claytonsilva/opendataday-es-2015
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/mtrpires/raspafamilia
#
# Extraindo contribuidores de: https://api.github.com/repos/supermae/dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/emilysoueu/transparencia-ma
#
# Extraindo contribuidores de: https://api.github.com/repos/afonsojota/seligabrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/mariohmol/voos-fab
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonlead/gastos-gov-federal
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama-firebase
#
# Extraindo contribuidores de: https://api.github.com/repos/M3nin0/scraping-bolsa-esmola
#
# Extraindo contribuidores de: https://api.github.com/repos/RobotsHoldingHands/Nome-Genero-Machine-Learning
#
# Extraindo contribuidores de: https://api.github.com/repos/KarlaMembreno/Determinantes-da-Corrupcao-na-America-Latina-e-Caribe
#
# Extraindo contribuidores de: https://api.github.com/repos/netoferraz/people-analytics-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/lucas000/PoliticoNaMao
#
# Extraindo contribuidores de: https://api.github.com/repos/VictorDeon/DadosDoGoverno
#
# Extraindo contribuidores de: https://api.github.com/repos/gabrielclages/study_pedaladasfiscais
#
# Extraindo contribuidores de: https://api.github.com/repos/cvarda/transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/karenyov/dadosPoliticos
#
# Extraindo contribuidores de: https://api.github.com/repos/luanoliveira1992/dadosBrasil
#
# Extraindo contribuidores de: https://api.github.com/repos/mgaldino/gov_federal
#
# Extraindo contribuidores de: https://api.github.com/repos/Macmod/PortalTransparenciaBR
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/dados.es.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/Pantoja87/Big_Data_PySpark_Viagem
#
# Extraindo contribuidores de: https://api.github.com/repos/LuizPhelipe/Or-amento-Publico
#
# Extraindo contribuidores de: https://api.github.com/repos/guisaulo/IBD-PAC2
#
# Extraindo contribuidores de: https://api.github.com/repos/danilolimadutra/dados-abertos-governo
#
# Extraindo contribuidores de: https://api.github.com/repos/biigue/CancerData
#
# Extraindo contribuidores de: https://api.github.com/repos/duarteguilherme/avaliacao_governo
#
# Extraindo contribuidores de: https://api.github.com/repos/chrislucas/explorando-dados-abertos-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/brunojardim/Cetus
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/mateushtoledo/sysvis
#
# Extraindo contribuidores de: https://api.github.com/repos/aldo2102/ELT-Pentaho-ClientRest-Com-Paginacao
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoDadosAbertosImpacta
#
# Extraindo contribuidores de: https://api.github.com/repos/GabrielLimaSnT/ProjetoOpeDadosAbertos
#
# Extraindo contribuidores de: https://api.github.com/repos/franciscogaluppo/Gastos-do-Governo-Federal
#
# Extraindo contribuidores de: https://api.github.com/repos/abevieiramota/dataset-gastos-diretos-federal
#
# Extraindo contribuidores de: https://api.github.com/repos/Carrilh0/IncendiosEmUnidadesDeConservacaoFederais
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/anuario-de-acidentes-previdencia
#
# Extraindo contribuidores de: https://api.github.com/repos/joaofresende/ClassifDesclassif
#
# Extraindo contribuidores de: https://api.github.com/repos/paulohubert/resultado_primario
#
# Extraindo contribuidores de: https://api.github.com/repos/Panizzo/transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/marcotmotta/ibd-query-project
#
# Extraindo contribuidores de: https://api.github.com/repos/antonivargas/desafio-camara
#
# Extraindo contribuidores de: https://api.github.com/repos/ppKrauss/getcsv_stdOpenGov
#
# Extraindo contribuidores de: https://api.github.com/repos/ces-jf/PSPA
#
# Extraindo contribuidores de: https://api.github.com/repos/VitorRoque/Analise-Fila-o-Politica-BR
#
# Extraindo contribuidores de: https://api.github.com/repos/danielmarcelino/rRAIS
#
# Extraindo contribuidores de: https://api.github.com/repos/nosdeedson/Projeto-leitura-de-API-com-Docker
#
# Extraindo contribuidores de: https://api.github.com/repos/chrmorais/scrapygdf
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/Dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/beluzo/ideo
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/TCC
#
# Extraindo contribuidores de: https://api.github.com/repos/enzoroiz/IBD-TP2
#
# Extraindo contribuidores de: https://api.github.com/repos/leobrj/camaraemfoco
#
# Extraindo contribuidores de: https://api.github.com/repos/VRPazdeJesus/multas-ibama
#
# Extraindo contribuidores de: https://api.github.com/repos/theuves/fddagudds
#
# Extraindo contribuidores de: https://api.github.com/repos/wiltomar/pySPED
#
# Extraindo contribuidores de: https://api.github.com/repos/wiltomar/jSPED
#
# Extraindo contribuidores de: https://api.github.com/repos/Glautor/participe-db
#
# Extraindo contribuidores de: https://api.github.com/repos/ValescaL/National-conferences-Conferencias-nacionais
#
# Extraindo contribuidores de: https://api.github.com/repos/sjcdigital/repasse-server
#
# Extraindo contribuidores de: https://api.github.com/repos/campagnucci/dados-abertos-gov-br
#
# Extraindo contribuidores de: https://api.github.com/repos/analytics-ufcg/compras-gov
#
# Extraindo contribuidores de: https://api.github.com/repos/KarlaMembreno/Determinantes-da-Corrupcao-na-America-Latina-e-Caribe
#
# Extraindo contribuidores de: https://api.github.com/repos/cvarda/transparencia
#
# Extraindo contribuidores de: https://api.github.com/repos/mgaldino/gov_federal
#
# Extraindo contribuidores de: https://api.github.com/repos/Pantoja87/Big_Data_PySpark_Viagem
#
# Extraindo contribuidores de: https://api.github.com/repos/paulohubert/resultado_primario
#
# Extraindo contribuidores de: https://api.github.com/repos/ces-jf/PSPA
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/Dashboard
#
# Extraindo contribuidores de: https://api.github.com/repos/SabrinyBezerra/TCC
# Extraindo contribuidores de: https://api.github.com/repos/BrunnaMaiaradaSilva/Analise-de-Dados-Com-R
#
# Extraindo contribuidores de: https://api.github.com/repos/bovino/cidprojetoaplicado
#
# Extraindo contribuidores de: https://api.github.com/repos/geraldo7junior/-chega-
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonmottac/go-to-doc
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/mtrpires/raspafamilia
#
# Extraindo contribuidores de: https://api.github.com/repos/edsonlead/gastos-gov-federal
#
# Extraindo contribuidores de: https://api.github.com/repos/Macmod/PortalTransparenciaBR
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/dados.es.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/mateushtoledo/sysvis
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/nosdeedson/Projeto-leitura-de-API-com-Docker
#
# Extraindo contribuidores de: https://api.github.com/repos/Glautor/participe-db
#
# Extraindo contribuidores de: https://api.github.com/repos/kerollaine/eaicongresso
#
# Extraindo contribuidores de: https://api.github.com/repos/mauriciovll/Dados-Abertos-SC-versao-TESTE-
#
# Extraindo contribuidores de: https://api.github.com/repos/NivSoft/transpy
#
# Extraindo contribuidores de: https://api.github.com/repos/dadosgovbr/ckanext-dadosgovbr
#
# Extraindo contribuidores de: https://api.github.com/repos/thenets/ckanext-dadosabertos
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/dados.es.gov.br
#
# Extraindo contribuidores de: https://api.github.com/repos/prodest/ckanext-data_es_theme
#
# Extraindo contribuidores de: https://api.github.com/repos/mateushtoledo/sysvis
# CPU times: user 19.7 s, sys: 804 ms, total: 20.5 s
# Wall time: 8min 9s

# %%
result_contributors.describe()
# Out:
#          repo_id                            repo_name  \
# count       1076                                 1076
# unique       386                                  386
# top     86646585  decosoares/diariasservidoresalagoas
# freq         315                                  315
#
#                                                  repo_url  \
# count                                                1076
# unique                                                386
# top     https://github.com/decosoares/diariasservidore...
# freq                                                  315
#
#                                              repo_api_url  contributor_id  \
# count                                                1076            1076
# unique                                                386             773
# top     https://api.github.com/repos/decosoares/diaria...         1058414
# freq                                                  315              21
#
#        contributor_login contributor_type  \
# count               1076             1076
# unique               773                2
# top     augusto-herrmann             User
# freq                  21             1073
#
#                             contributor_url  \
# count                                  1076
# unique                                  773
# top     https://github.com/augusto-herrmann
# freq                                     21
#
#                                   contributor_api_url timestamp_extract
# count                                            1076              1076
# unique                                            773               401
# top     https://api.github.com/users/augusto-herrmann        1573185522
# freq                                               21               232

# %%
result_contributors.head()
# Out:
#     repo_id                          repo_name  \
# 0  29256552   CamaraDosDeputados/dados-abertos
# 1  29256552   CamaraDosDeputados/dados-abertos
# 2  29256552   CamaraDosDeputados/dados-abertos
# 3  29256552   CamaraDosDeputados/dados-abertos
# 4  39256926  dadosgovbr/catalogos-dados-brasil
#
#                                             repo_url  \
# 0  https://github.com/CamaraDosDeputados/dados-ab...
# 1  https://github.com/CamaraDosDeputados/dados-ab...
# 2  https://github.com/CamaraDosDeputados/dados-ab...
# 3  https://github.com/CamaraDosDeputados/dados-ab...
# 4  https://github.com/dadosgovbr/catalogos-dados-...
#
#                                         repo_api_url contributor_id  \
# 0  https://api.github.com/repos/CamaraDosDeputado...       19875696
# 1  https://api.github.com/repos/CamaraDosDeputado...       16920325
# 2  https://api.github.com/repos/CamaraDosDeputado...       19963732
# 3  https://api.github.com/repos/CamaraDosDeputado...        7976552
# 4  https://api.github.com/repos/dadosgovbr/catalo...        1058414
#
#       contributor_login contributor_type  \
# 0         FabricioRocha             User
# 1  EquipeDadosAbertosCD             User
# 2         JoaoCarabetta             User
# 3             labhacker             User
# 4      augusto-herrmann             User
#
#                            contributor_url  \
# 0         https://github.com/FabricioRocha
# 1  https://github.com/EquipeDadosAbertosCD
# 2         https://github.com/JoaoCarabetta
# 3             https://github.com/labhacker
# 4      https://github.com/augusto-herrmann
#
#                                  contributor_api_url timestamp_extract
# 0         https://api.github.com/users/FabricioRocha        1573185219
# 1  https://api.github.com/users/EquipeDadosAbertosCD        1573185219
# 2         https://api.github.com/users/JoaoCarabetta        1573185219
# 3             https://api.github.com/users/labhacker        1573185219
# 4      https://api.github.com/users/augusto-herrmann        1573185220

# %%
file_path = '../data/contributors_' + str(time.time()).split('.')[0] + '.csv'
file_path
# Out:
# '../data/contributors_1573185829.csv'

# %%
result_contributors.to_csv(file_path, index=False)
